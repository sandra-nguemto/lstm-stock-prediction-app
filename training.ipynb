# %%
from train import TrainerAll
from configs import config, stocks

# %%
trainer = TrainerAll(config, stocks)

# %%
trainer.train_all()
# Out:
# Training Walmart-------------------
# Epoch[1/100] | loss train:0.009474, test:0.008067 | lr:0.010000
# Epoch[2/100] | loss train:0.000662, test:0.005872 | lr:0.010000
# Epoch[3/100] | loss train:0.000524, test:0.004048 | lr:0.010000
# Epoch[4/100] | loss train:0.000385, test:0.003784 | lr:0.010000
# Epoch[5/100] | loss train:0.000352, test:0.003756 | lr:0.010000
# Epoch[6/100] | loss train:0.000301, test:0.003918 | lr:0.010000
# Epoch[7/100] | loss train:0.000245, test:0.003551 | lr:0.010000
# Epoch[8/100] | loss train:0.000275, test:0.005632 | lr:0.010000
# Epoch[9/100] | loss train:0.000213, test:0.008560 | lr:0.010000
# Epoch[10/100] | loss train:0.000283, test:0.003310 | lr:0.010000
# Epoch[11/100] | loss train:0.000283, test:0.004673 | lr:0.010000
# Epoch[12/100] | loss train:0.000252, test:0.004552 | lr:0.010000
# Epoch[13/100] | loss train:0.000214, test:0.003954 | lr:0.010000
# Epoch[14/100] | loss train:0.000236, test:0.003433 | lr:0.010000
# ...
